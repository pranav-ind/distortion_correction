# %%
import torch
import matplotlib.pyplot as plt
import kornia as K
import torchfields
from tqdm import tqdm
import torchvision.transforms.functional as F1
from torchvision.transforms import v2

from matplotlib import pyplot as plt
import torch.nn.functional as F
from utils import viewer_3d,show_mv,plt_images,complex_pyramid,complex_NLL,complex_total_variation
from data_loader import slicing

# %%
f_pos = torch.load('/Users/pi58/Library/CloudStorage/Box-Box/PhD/Low Field Data-1/20230213 - Chloe for Itamar/TSEV3_1_highGrad/1/k_space.t')
f_inv = torch.load("/Users/pi58/Library/CloudStorage/Box-Box/PhD/Low Field Data-1/20230213 - Chloe for Itamar/TSEV3_1_highGrad_invPol/1/k_space.t")
# img_inv = torch.flip(img_inv,[0])

# img_pos = torch.fft.ifftshift(torch.fft.ifftn(f_pos))  # Inverse FFT
# img_inv = torch.fft.ifftshift(torch.fft.ifftn(f_inv))

# f_pos, f_inv, img_pos, img_inv = slicing(img_pos, img_inv)

# %%
print(f_pos.shape)
# Out:
# torch.Size([100, 110, 220])

# %%
import torchvision.transforms as Tr
def kspace_image(k_space):

    # Takes 3D k-space data and returns the 3D FT and 3D Image
    img = torch.fft.ifftn(k_space)  # Inverse FFT
    img = torch.fft.ifftshift(img)
    img = torch.abs(img)
    transform = Tr.CenterCrop(220)
    # print(img.dtype)
    img = transform(img.float())
    print(img.dtype)
    # pad = (10,10,10,10)
    # img = F.pad(img,pad,"constant",0)

    # f = torch.fft.fftn(img)  # Convert the image to k-space

    return img

# %%
a = kspace_image(f_pos)
b = kspace_image(f_inv)
# Out:
# torch.float32
# torch.float32

# %%
a.shape
# Out:
# torch.Size([100, 220, 220])

# %%
slices = [15, 16, 17, 18, 19]
z = [(a), (b)]
plt_images(slices,z,"Row-1 : img_pos, Row-2 : img_inv",0 , 0.0002)
print(z[0].shape, z[1].shape)
# Out:
# torch.Size([100, 220, 220]) torch.Size([100, 220, 220])

# %%
w = torch.Field.identity(1,2,27,27,requires_grad=True)

template_image_list = []
w_list = []
losses = []

# %%
f_pos = f_pos.reshape(1,f_pos.shape[-3],f_pos.shape[-1],f_pos.shape[-1])
f_inv = f_inv.reshape(1,f_pos.shape[-3],f_pos.shape[-1],f_pos.shape[-1])

img_pos_pyramid = K.geometry.transform.build_pyramid(img_pos.reshape(1,img_pos.shape[-3],img_pos.shape[-1],img_pos.shape[-1]),4)
img_inv_pyramid = K.geometry.transform.build_pyramid(img_inv.reshape(1,img_pos.shape[-3],img_pos.shape[-1],img_pos.shape[-1]),4)

f_pos_pyramid = complex_pyramid(f_pos.reshape(1,f_pos.shape[-3],f_pos.shape[-1],f_pos.shape[-1]))
f_inv_pyramid = complex_pyramid(f_inv.reshape(1,f_pos.shape[-3],f_pos.shape[-1],f_pos.shape[-1]))

z1 = img_pos_pyramid[0].reshape(35,220,220)
z2 = img_inv_pyramid[0].reshape(35,220,220)
z4 = torch.abs(torch.fft.ifftn(f_pos_pyramid[0])).reshape(35,220,220)
z5 = torch.abs(torch.fft.ifftn(f_inv_pyramid[0])).reshape(35,220,220)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 f_pos = f_pos.reshape(1,f_pos.shape[-3],f_pos.shape[-1],f_pos.shape[-1])
#       2 f_inv = f_inv.reshape(1,f_pos.shape[-3],f_pos.shape[-1],f_pos.shape[-1])
#       4 img_pos_pyramid = K.geometry.transform.build_pyramid(img_pos.reshape(1,img_pos.shape[-3],img_pos.shape[-1],img_pos.shape[-1]),4)
#
# RuntimeError: shape '[1, 100, 220, 220]' is invalid for input of size 2420000
